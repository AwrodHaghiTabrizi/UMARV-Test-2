# %% [markdown]
# #Import libraries

# %%
import os
import sys
from getpass import getpass
import git
import dropbox
import torch.optim as optim

# %% [markdown]
# #Configure environment

# %%
os.environ["ENVIRONMENT"] = "windows"
os.environ["REPO_DIR"] = git.Repo(search_parent_directories=True).git.rev_parse("--show-toplevel")
os.environ["ROOT_DIR"] = os.path.abspath(os.path.join(os.getenv("REPO_DIR"), os.pardir))
os.environ["MODEL_ID"] = "2xztk0ah"
os.environ["MODEL_DIR"] = f"{os.getenv('REPO_DIR')}/models/model_{os.getenv('MODEL_ID')}"

# %% [markdown]
# #Import repository resources

# %%
sys.path.append(f"{os.getenv('REPO_DIR')}/src")
from helpers import *

sys.path.append(f"{os.getenv('MODEL_DIR')}/src")
from methods import *
from architecture import *

# %% [markdown]
# #Download datasets

# %%
# dbx_access_token = getpass("Enter your DropBox access token: ")

# %%
# download_datasets_from_dropbox(
#     dbx_access_token = dbx_access_token,
#     include_all_datasets = True,
#     use_thread = True
# )

# %% [markdown]
# #Code

# %%
num_epochs = 50
batch_size = 32
val_size = 25

# %%
device = set_device()
model = initialize_model(device=device, reset_weights=True)

train_dataset, val_dataset, benchmark_dataset = create_datasets(
    device = device,
    include_all_datasets=False,
    include_real_world_datasets=True
)

train_dataloader, val_dataloader, benchmark_dataloader = create_dataloaders(
    train_dataset = train_dataset,
    val_dataset = val_dataset,
    benchmark_dataset = benchmark_dataset,
    batch_size = batch_size,
    val_size = val_size
)

optimizer = optim.SGD(model.parameters(), lr=0.05, momentum=0.9)
criterion = nn.CrossEntropyLoss()
# Out:
# Using the GPU! :)

# %%
model, train_loss_hist, val_performance_hist, best_val_performance = training_loop(
    model = model,
    criterion = criterion,
    optimizer = optimizer,
    train_dataloader = train_dataloader,
    val_dataloader = val_dataloader,
    device = device,
    num_epochs = num_epochs,
    auto_stop = True,
    auto_stop_patience = 10,
)
# Out:
# Training:   0%|          | 0/50 [00:00<?, ?epoch/s]
# Epoch: 1/50  <>  Train Loss: 0.6519  <>  Val Acc: 51.02%  <>  Val Precision: 0.41%
# Epoch: 5/50  <>  Train Loss: 0.1555  <>  Val Acc: 51.57%  <>  Val Precision: 0.40%
# Epoch: 10/50  <>  Train Loss: 0.0923  <>  Val Acc: 51.28%  <>  Val Precision: 0.41%
# Epoch: 14/50  <>  Train Loss: 0.0823  <>  Val Acc: 51.08%  <>  Val Precision: 0.40%
# Training auto stopped. No improvement in validation accuracy for 10 epochs.

# %%
graph_loss_history(train_loss_hist)

graph_performance_history(
    performance_hist = val_performance_hist,
    split = 'Val',
    metrics = ["Accuracy", "Precision"]
)

show_sample_results(
    model = model,
    dataset = train_dataset,
    device = device,
)

# %%
show_sample_results(
    model = model,
    dataset = train_dataset,
    device = device,
)

# %%
test_model_on_benchmarks(
    model = model,
    device = device,
    all_benchmarks = True,
    report_results = True
)
# Out:
# Results successfully reported.
#
# benchmark_1 metrics:
# 	TN Rate: 0.5189
# 	FP Rate: 0.4811
# 	TP Rate: 0.4893
# 	FN Rate: 0.5107
# 	Accuracy: 0.5188
# 	Precision: 0.0030
# 	Recall: 0.4893
# 	Specificity: 0.5189
# 	F1 Score: 0.0060
# 	IoU Lane: 0.0030
# 	IoU Background: 0.5181
# 	Mean IoU: 0.2606
# 	Pixel Accuracy: 0.5188
# 	Mean Pixel Accuracy: 0.2606
# 	Frequency-Weighted IoU: 0.5166
# 	Dice Coefficient: 0.0060
# 	Boundary F1 Score: 0.0060
